# %%
# Lab One: Lab-Assignment 1

"""Write a program to create 3 variables for 3 test scores, and then calculate the total and average of the scores.
Print the total and average scores."""


test_1 = 85
test_2 = 90
test_3 = 78

total_score = test_1 + test_2 + test_3
average_score = total_score / 3
print("Total Score:", total_score)
print("Average Score:", f"{average_score: .2f}")
# Out:
# Total Score: 253
# Average Score:  84.33

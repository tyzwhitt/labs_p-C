# %% [markdown]
# Lab Assignment 4
#
# Create the following list in Python:
#
# 22, 45, 78, 98, 100.
#
# Without using any in-built function such as count(), find out the number of items in the list.

# %%
# create list
num_list = [22, 45, 78, 98, 100]

# %%
i = 0
for x in num_list:
    i += 1
print(f"Number of items in the list: {i}")
# Out:
# Number of items in the list: 5

# %% [markdown]
# Complete Program-5 on car analysis from Lesson-9 posted on Blackboard. Submit PDF document with Python Code and Screenshot of Visual.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('car.csv')
df.head()
# Out:
#    Index  distance traveled  starting point
# 0    241              31.38              12
# 1    242              30.38              12
# 2    243              33.63              12
# 3    244              26.63               9
# 4    245              25.75               9

# %% [markdown]
# Program 5:
#
# import pandas as pd
#
# import matplotlib.pyplot as plt
#
# df = pd.read_csv('car.csv')
#
# df.plot(kind = 'scatter',x = 'distance traveled', y = 'starting point')
#
# plt.title("Analysis of Relationship between Distance Travelled and Starting Point")
#
# plt.xlabel('Total Distance Travelled')
#
# plt.ylabel('Car Starting Point')
#
# plt.show()

# %%
df.plot(kind='scatter', x='distance traveled', y='starting point')

plt.title("Analysis of Relationship between Distance Traveled and Starting Point")

plt.xlabel("Total Distance Traveled")
plt.ylabel("Car Starting Point")
plt.show()

# %%
df.head()
# Out:
#    Index  distance traveled  starting point
# 0    241              31.38              12
# 1    242              30.38              12
# 2    243              33.63              12
# 3    244              26.63               9
# 4    245              25.75               9
